# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.llms import Tongyi

llm = Tongyi()

# %% [markdown]
# # 阻塞模式

# %%
llm.invoke("有什么关于失业和通货膨胀的相关性的理论")
# Out:
# '关于**失业与通货膨胀**之间的相关性，最著名的理论是 **菲利普斯曲线（Phillips Curve）**。这个理论最早由新西兰经济学家 **阿尔班·威廉·菲利普斯（A.W. Phillips）** 在1958年提出，他在研究英国1861年至1957年的数据时发现：**失业率与工资增长率之间存在一种负相关关系**。后来经济学家将这一关系扩展到通货膨胀与失业之间的关系。\n\n---\n\n## 一、菲利普斯曲线的基本观点\n\n### 1. **原始菲利普斯曲线**\n菲利普斯发现：当**失业率较低时，工资增长较快**；而当**失业率较高时，工资增长较慢**。这表明：\n\n- 劳动力市场紧张（低失业） → 企业提高工资以吸引工人 → 工资上涨 → 企业成本上升 → 物价上涨（通货膨胀）。\n- 劳动力市场疲软（高失业） → 工资增长缓慢甚至下降 → 成本压力小 → 通货膨胀率低甚至出现通货紧缩。\n\n### 2. **现代形式的菲利普斯曲线**\n后来经济学家（如萨缪尔森、索洛）将其扩展为：\n> **通货膨胀率与失业率之间存在短期的负相关关系**。\n\n这成为政策制定者在“稳定通胀”和“降低失业”之间进行权衡的理论依据。\n\n---\n\n## 二、适应性预期与菲利普斯曲线的演变\n\n20世纪60年代末至70年代，经济学家如 **米尔顿·弗里德曼（Milton Friedman）** 和 **埃德蒙·费尔普斯（Edmund Phelps）** 提出了对菲利普斯曲线的修正：\n\n### 1. **长期菲利普斯曲线（Vertical Phillips Curve）**\n他们指出：\n- 在短期内，可能存在通货膨胀与失业的负相关关系；\n- 但在**长期内，失业率会回到一个“自然失业率”水平（Natural Rate of Unemployment）**，与通货膨胀无关。\n\n> 这意味着：**长期中，货币政策无法通过制造通胀来降低失业**。\n\n### 2. **适应性预期（Adaptive Expectations）**\n人们会根据过去的经验来预测未来的通货膨胀。如果政府持续使用通胀来降低失业，人们会预期更高的通胀，最终导致：\n- 实际工资不变，失业率回升；\n- 但通货膨胀率却持续上升。\n\n这就是所谓的“**滞胀（stagflation）**”现象，在20世纪70年代美国经济中得到了验证。\n\n---\n\n## 三、理性预期与新古典综合\n\n### 1. **理性预期（Rational Expectations）**\n由卢卡斯等人提出：人们会利用所有可得信息来预测未来，而不仅仅是依赖过去的经验。\n\n### 2. **新古典综合（New Classical Macroeconomics）**\n认为：\n- 如果公众有理性预期，那么**任何可预测的货币政策都不会影响实际产出和失业率**；\n- 只有“未预期到的”政策才会影响经济。\n\n### 3. **新凯恩斯主义（New Keynesian Economics）**\n保留了价格和工资粘性的观点，认为即使在理性预期下，**短期菲利普斯曲线仍然存在**，但其位置会随预期而变动。\n\n---\n\n## 四、现代菲利普斯曲线（混合菲利普斯曲线）\n\n现代宏观经济学中，通常使用的是“**混合菲利普斯曲线（Hybrid Phillips Curve）**”，它结合了：\n- **预期通货膨胀**\n- **滞后通货膨胀**\n- **产出缺口（或失业缺口）**\n- **供给冲击（如油价）**\n\n其基本形式为：\n\n$$\n\\pi_t = \\beta E_t[\\pi_{t+1}] + \\kappa y_t + (1-\\beta)\\pi_{t-1}\n$$\n\n其中：\n- $\\pi_t$：当期通货膨胀率\n- $E_t[\\pi_{t+1}]$：对未来通胀的预期\n- $y_t$：产出缺口（或失业缺口）\n- $\\kappa$：产出对通胀的影响系数\n\n---\n\n## 五、实证表现与争议\n\n- **20世纪70年代**：美国等国家出现“滞胀”（高通胀 + 高失业），挑战了原始菲利普斯曲线。\n- **2008年金融危机后**：通胀与失业的关系变得模糊，部分国家即使失业率下降，通胀仍保持低迷。\n- **2020年代以来**：一些国家在失业率下降的同时出现高通胀（如美国2021-2023），又重新唤起对菲利普斯曲线的关注。\n\n---\n\n## 六、政策意义\n\n- **短期**：政策制定者可以在通胀与失业之间进行权衡（如通过货币政策刺激经济）。\n- **长期**：应关注结构性改革、自然失业率和通胀预期管理。\n- **中央银行**通常以控制通胀为目标，但也会关注就业市场状况（如美联储的“双重使命”）。\n\n---\n\n## 总结\n\n| 理论 | 核心观点 | 时间 |\n|------|-----------|------|\n| 原始菲利普斯曲线 | 失业率与工资增长率负相关 | 1958年 |\n| 现代菲利普斯曲线 | 失业率与通胀率负相关（短期） | 1960年代 |\n| 长期菲利普斯曲线 | 长期内失业率与通胀无关（自然失业率） | 1960-70年代 |\n| 适应性预期理论 | 通胀预期影响菲利普斯曲线位置 | 1970年代 |\n| 理性预期与新古典理论 | 可预期政策无效，只有未预期的政策有效 | 1970-80年代 |\n| 新凯恩斯主义 | 价格粘性下短期菲利普斯曲线仍然存在 | 1980年代至今 |\n| 混合菲利普斯曲线 | 结合预期、滞后通胀与产出缺口 | 当代模型 |\n\n---\n\n如果你需要更深入的数学模型、图形解释、实证分析或结合具体国家案例（如美国、中国），我可以继续为你详细展开。'

# %% [markdown]
# # 流式模式

# %%
for chunk in llm.stream(
    "有什么关于失业和通货膨胀的相关性的理论"
):
    print(chunk, end="\n", flush=True)
# Out:
# 关于
# **
# 失业与
# 通货膨胀
# **之间的关系，经济学
# 中有一个非常著名的
# 理论，叫做：
#
#
# ---
#
# ###
#  📌 **菲利普斯
# 曲线（Phillips Curve）
# **
#
# 这是由新西兰
# 经济学家 **A.W
# . 菲利
# 普斯（A.W.
#  Phillips）** 在
# 1958
# 年提出的一个经验
# 观察，后来被
# 广泛用于宏观经济学中
# 。
#
# #### 🔹
#  原始
# 菲利普斯曲线的核心
# 观点：
# > **
# 短期内，失业率与通
# 货膨胀率之间存在
# 一种负相关的关系。
# **
#
# 也就是说：
# - 当失业
# 率较低时，通
# 货膨胀率较高
# ；
# - 当失业率较高
# 时，通货膨胀
# 率较低。
#
# 这
# 可以用一个简单的曲线图
# 来表示：横
# 轴是失业率，纵
# 轴是通货膨胀
# 率，曲线向
# 右下方倾斜。
#
# ####
#  🧠 直观解释
# ：
# - 低失业意味着
# 劳动力市场紧张，企业
# 为了争夺工人必须
# 提高工资；
# -
#  工资上涨会
# 推高生产成本，进而
# 导致商品价格上涨（
# 即通货膨胀
# ）；
# -
#  反之，高
# 失业率下工资
# 增长缓慢或下降
# ，通货膨胀
# 率也较低。
#
# ---
#
#
# ### 🧩
#  短期 vs
#  长期
# 菲利普斯
# 曲线
#
# #### 1.
#  **短期菲利普斯
# 曲线（SRPC）**
#
# - 仍然保持
# 负相关性；
# -
#  政策制定者可以在
# 短期内通过货币政策或
# 财政政策在失业
# 与通胀之间进行
# 权衡（trade
# -off）；
# -
# 例如：扩张性政策可以
# 降低失业，但会
# 带来通胀。
#
# ####
# 2. **长期
# 菲利普斯曲线（
# LRPC）**
#
# - 由米尔
# 顿·弗里德曼
# （Milton Friedman）和
# 埃德蒙·菲尔
# 普斯（Edmund Phelps
# ）等人在2
# 0世纪60年代末
# 提出；
# - 他们
# 认为，**在
# 长期中，失业率
# 不会低于“自然失业率
# ”（Natural Rate of Un
# employment）**，无论
# 通胀如何变化；
#
# - 所以
# ，**长期菲
# 利普斯曲线是一
# 条垂直线，
# 位于自然失业率的位置
# **；
# -
#  意味着：**
# 长期中，通胀
# 与失业之间没有稳定
# 的关系**。
#
# ---
#
# ###
#  🧠 适应
# 性预期 vs
#  理性预期
#
#
# #### 1. **适应
# 性预期（Adaptive
#  Expectations）**
# -
# 人们根据过去的经验来
# 预测未来通胀；
# -
#  这会导致“通胀惯
# 性”：一旦
# 通胀上升，人们
# 预期它会继续上升，
# 从而推动进一步的
# 通胀。
#
# #### 2
# . **理性预期（R
# ational Expectations）**
# -
#  由卢卡斯（
# Robert Lucas）等人发展
# ；
# - 人们
# 使用所有可得信息
# 来预测未来；
#
# - 这导致
# 政策效果被预期
# 到，从而削弱
# 了短期菲利普斯
# 曲线的稳定性。
#
#
# ---
#
# ### 💥
# 20世纪70年代
# 的“滞胀”挑战
#
#
# - 1
# 970年代，美国
# 等国家出现了**
# 高失业率与
# 高通货膨胀并
# 存**的现象（
# 称为“滞胀
# ”Stagflation）
# ；
# - 这与
# 原始菲利普
# 斯曲线的预测
# 不符；
# -
#  导致经济学家重新思考
# 失业与通胀的关系
# ；
# - 从而
# 推动了**新
# 凯恩斯主义
# **和**新古典
# 综合**的发展。
#
# ---
#
#
# ### 📚
#  其他相关
# 理论与模型
#
# |
#  理论名称 |
#  核心观点
#  |
# |----------|----------|
#
# | **新凯恩斯
# 主义菲利普斯
# 曲线（New Keynesian
#  Phillips Curve, NKPC
# ）** |
#  强调价格粘性和
# 理性预期，认为
# 通胀取决于预期通胀
# 和实际经济活动的
# 波动。 |
# |
#  **混合菲利普斯
# 曲线（Hybrid Phillips
#  Curve）** |
#  包括预期通胀和滞后
# 通胀，更符合
# 现实数据。 |
# |
#  **奥肯定律（Ok
# un's Law）** |
#  描述GDP增长与
# 失业率之间的关系，间接
# 与通胀相关。 |
# |
#  **货币主义观点
# （Monetarism）
# ** | 认为通胀
# 始终且处处是一种货币现象
# ，长期中与
# 失业无关。 |
#
# ---
#
# ###
#  📌
#  总结
#
# |
#  时期 |
#  失业与通胀
# 的关系 |
# |------
# |------------------|
# | **
# 短期** |
#  负相关（菲
# 利普斯曲线成立
# ） |
# | **长期**
#  | 无稳定
# 关系，失业率回归
# 自然率 |
# | **
# 政策启示** |
#  短期内可
# 权衡，长期
# 无效 |
#
# ---
#
# 如果你是
# 学生或研究者
# ，可以进一步研究：
#
# - 新凯恩斯主义
# 菲利普斯曲线的
# 微观基础；
# -
# 通胀目标制（In
# flation Targeting）对
# 菲利普斯
# 曲线的影响；
# -
# 2008年金融危机
# 后“平坦的
# 菲利普斯曲线”
# 现象；
# - 当
# 前（202
# 0年代）关于
# 菲利普斯
# 曲线是否“扁
# 平化”的争论
# 。
#
# ---
#
# 需要我帮你整理
# 一份图表或案例
# 分析吗？

# %%
responses = llm.batch(
    [
        "简单介绍一个唐代诗人",
        "简单介绍一个宋代诗人"
    ]
)
responses
# Out:
# ['好的！下面简单介绍一位著名的唐代诗人：\n\n**李白（701年－762年）**\n\n李白，字太白，号青莲居士，是唐代最著名的浪漫主义诗人之一，被誉为“诗仙”。他出生于西域碎叶城（今吉尔吉斯斯坦境内），后随家迁居四川江油。李白才华横溢、性格豪放，喜欢饮酒作诗，游历名山大川，作品充满想象力和豪迈气概。\n\n他的诗歌题材广泛，包括山水、饮酒、友情、边塞等，语言清新自然，感情奔放，富有浪漫主义色彩。代表作有《静夜思》《将进酒》《望庐山瀑布》《早发白帝城》等。\n\n李白一生仕途不顺，但他的诗歌影响深远，至今仍被广泛传诵，被认为是中国古代诗歌史上最耀眼的明星之一。',
#  '好的！下面简单介绍一位著名的宋代诗人：\n\n**苏轼（1037年－1101年）**\n\n苏轼，字子瞻，号东坡居士，世称苏东坡，是北宋时期最杰出的文学家、书画家之一。他是“唐宋八大家”之一，与父亲苏洵、弟弟苏辙并称“三苏”。\n\n**主要成就：**  \n- 在诗歌方面，苏轼题材广泛，风格豪放洒脱，善于抒发情感和哲理，代表作如《题西林壁》《饮湖上初晴后雨》等。  \n- 他是豪放词派的开创者，代表作如《念奴娇·赤壁怀古》《水调歌头·明月几时有》等，至今广为传诵。  \n- 他还擅长散文、书法和绘画，是中国文化史上罕见的全才。\n\n**性格与人生：**  \n苏轼为人正直、豁达乐观，但仕途坎坷，多次被贬。他在被贬黄州期间，写下了许多千古名篇，并自号“东坡居士”。\n\n苏轼的作品情感真挚、思想深刻，展现了他丰富的人生阅历和超脱的精神境界，对后世影响深远。']

# %%
for response in responses:
    print(response)
    print("-" * 100)
# Out:
# 好的！下面简单介绍一位著名的唐代诗人：
#
# **李白（701年－762年）**
#
# 李白，字太白，号青莲居士，是唐代最著名的浪漫主义诗人之一，被誉为“诗仙”。他出生于西域碎叶城（今吉尔吉斯斯坦境内），后随家迁居四川江油。李白才华横溢、性格豪放，喜欢饮酒作诗，游历名山大川，作品充满想象力和豪迈气概。
#
# 他的诗歌题材广泛，包括山水、饮酒、友情、边塞等，语言清新自然，感情奔放，富有浪漫主义色彩。代表作有《静夜思》《将进酒》《望庐山瀑布》《早发白帝城》等。
#
# 李白一生仕途不顺，但他的诗歌影响深远，至今仍被广泛传诵，被认为是中国古代诗歌史上最耀眼的明星之一。
# ----------------------------------------------------------------------------------------------------
# 好的！下面简单介绍一位著名的宋代诗人：
#
# **苏轼（1037年－1101年）**
#
# 苏轼，字子瞻，号东坡居士，世称苏东坡，是北宋时期最杰出的文学家、书画家之一。他是“唐宋八大家”之一，与父亲苏洵、弟弟苏辙并称“三苏”。
#
# **主要成就：**
# - 在诗歌方面，苏轼题材广泛，风格豪放洒脱，善于抒发情感和哲理，代表作如《题西林壁》《饮湖上初晴后雨》等。
# - 他是豪放词派的开创者，代表作如《念奴娇·赤壁怀古》《水调歌头·明月几时有》等，至今广为传诵。
# - 他还擅长散文、书法和绘画，是中国文化史上罕见的全才。
#
# **性格与人生：**
# 苏轼为人正直、豁达乐观，但仕途坎坷，多次被贬。他在被贬黄州期间，写下了许多千古名篇，并自号“东坡居士”。
#
# 苏轼的作品情感真挚、思想深刻，展现了他丰富的人生阅历和超脱的精神境界，对后世影响深远。
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # 自定义LLM

# %%
from typing import Any, Dict, Iterator, List, Mapping, Optional

from langchain_core.callbacks.manager import CallbackManagerForLLMRun
from langchain_core.language_models.llms import LLM
from langchain_core.outputs import GenerationChunk


class CustomLLM(LLM):
    """A custom chat model that echoes the first `n` characters of the input.

    When contributing an implementation to LangChain, carefully document
    the model including the initialization parameters, include
    an example of how to initialize the model and include any relevant
    links to the underlying models documentation or API.

    Example:

        .. code-block:: python

            model = CustomChatModel(n=2)
            result = model.invoke([HumanMessage(content="hello")])
            result = model.batch([[HumanMessage(content="hello")],
                                 [HumanMessage(content="world")]])
    """

    n: int
    """The number of characters from the last message of the prompt to be echoed."""

    def _call(
        self,
        prompt: str,
        stop: Optional[List[str]] = None,
        run_manager: Optional[CallbackManagerForLLMRun] = None,
        **kwargs: Any,
    ) -> str:
        """Run the LLM on the given input.

        Override this method to implement the LLM logic.

        Args:
            prompt: The prompt to generate from.
            stop: Stop words to use when generating. Model output is cut off at the
                first occurrence of any of the stop substrings.
                If stop tokens are not supported consider raising NotImplementedError.
            run_manager: Callback manager for the run.
            **kwargs: Arbitrary additional keyword arguments. These are usually passed
                to the model provider API call.

        Returns:
            The model output as a string. Actual completions SHOULD NOT include the prompt.
        """
        if stop is not None:
            raise ValueError("stop kwargs are not permitted.")
        return prompt[: self.n]

    def _stream(
        self,
        prompt: str,
        stop: Optional[List[str]] = None,
        run_manager: Optional[CallbackManagerForLLMRun] = None,
        **kwargs: Any,
    ) -> Iterator[GenerationChunk]:
        """Stream the LLM on the given prompt.

        This method should be overridden by subclasses that support streaming.

        If not implemented, the default behavior of calls to stream will be to
        fallback to the non-streaming version of the model and return
        the output as a single chunk.

        Args:
            prompt: The prompt to generate from.
            stop: Stop words to use when generating. Model output is cut off at the
                first occurrence of any of these substrings.
            run_manager: Callback manager for the run.
            **kwargs: Arbitrary additional keyword arguments. These are usually passed
                to the model provider API call.

        Returns:
            An iterator of GenerationChunks.
        """
        for char in prompt[: self.n]:
            chunk = GenerationChunk(text=char)
            if run_manager:
                run_manager.on_llm_new_token(chunk.text, chunk=chunk)

            yield chunk

    @property
    def _identifying_params(self) -> Dict[str, Any]:
        """Return a dictionary of identifying parameters."""
        return {
            # The model name allows users to specify custom token counting
            # rules in LLM monitoring applications (e.g., in LangSmith users
            # can provide per token pricing for their model and monitor
            # costs for the given LLM.)
            "model_name": "CustomChatModel",
        }

    @property
    def _llm_type(self) -> str:
        """Get the type of language model used by this chat model. Used for logging purposes only."""
        return "custom"

# %%
llm = CustomLLM(n=8)
print(llm)
# Out:
# CustomLLM
# Params: {'model_name': 'CustomChatModel'}

# %%
llm.invoke("This is a foobar thing")
# Out:
# 'This is '

# %%
for token in llm.stream("hello"):
    print(token, end="|", flush=True)
# Out:
# h|e|l|l|o|

# %%
llm.batch(["woof woof woof", "meow meow meow"])
# Out:
# ['woof woo', 'meow meo']

# %% [markdown]
# # 缓存

# %%
from langchain.globals import set_llm_cache
from langchain.cache import InMemoryCache

# %%
# set_llm_cache(InMemoryCache()) is setting up an in-memory cache for the LLM (Large Language Model) to store responses. Here's what it does:

# InMemoryCache(): Creates a cache that stores LLM responses in memory (RAM) rather than on disk or in a database.
# set_llm_cache(): Tells the LLM system to use this caching mechanism.

# %%
# %%time

set_llm_cache(InMemoryCache())

# The first time, it is not yet in cache, so it should take longer
llm.invoke("说一个笑话")
# Out:
# CPU times: user 430 µs, sys: 77 µs, total: 507 µs
# Wall time: 530 µs
# '说一个笑话'

# %%
# %%time

# The second time it is, so it goes faster
llm.invoke("说一个笑话")
# Out:
# CPU times: user 243 µs, sys: 10 µs, total: 253 µs
# Wall time: 259 µs
# '说一个笑话'

# %% [markdown]
# # 记录消耗tokens

# %%
from callbacks.manager import get_generic_llms_callback

with get_generic_llms_callback() as cb:
    llm.invoke("有什么关于失业和通货膨胀的相关性的理论")
    print(cb)
# Out:
# Error in GenericLLMsCallbackHandler.on_llm_end callback: TypeError("argument of type 'NoneType' is not iterable")
# Tokens Used: 0
# 	Prompt Tokens: 0
# 	Completion Tokens: 0
# Successful Requests: 0
# Total Cost (CYN): ¥0.0

# %%
from tongyi.llm import CustomTongyi

# dashscope_api_key作为参数传入
# 或者配置环境变量`DASHSCOPE_API_KEY`
llm = CustomTongyi()

with get_generic_llms_callback() as cb:
    for chunk in llm.stream(
    "有什么关于失业和通货膨胀的相关性的理论"):
        print(chunk, end="|", flush=True)
    print(cb)
# Out:
# 在|经济学|中|，失业和通货|膨胀之间的关系是通过几种主要理论|来解释的：
#
# 1. |菲利普斯曲线（Phillips| Curve）：这是最经典的理论，|由A.W.菲利普斯|在1958年提出。|该理论认为，失业率和通|货膨胀率之间存在负相关关系|，即当失业率降低时，|通货膨胀率会上升，反之|亦然。这是因为当经济接近充分|就业时，劳动力市场紧张，工资|和物价上涨压力增大，导致通胀|。
#
# 2. 新古典综合理论（|Neoclassical Synthesis）：|这一理论扩展了菲利普斯|曲线，认为在长期，失业率|会稳定在一个自然水平，这个水平|下的通货膨胀率与失业率|无关。但短期中，政策制定|者可以通过调整货币政策或财政政策在|失业和通胀之间做出权衡。
#
# |3. 滞胀理论（|Stagflation Theory）：20|世纪70年代的滞胀现象|（高失业和高通胀并存|）挑战了传统的菲利普斯|曲线。这表明，某些情况下，|如供给冲击（如石油危机），|失业和通胀可能同时上升，打破了|菲利普斯曲线的简单负|相关关系。
#
# 4. 长|期菲利普斯曲线（Long|-Run Phillips Curve）：新凯|恩斯主义经济学提出了长期菲利|普斯曲线，它认为，虽然|在短期内，政策可以影响失业和|通胀的关系，但在长期，通货|膨胀预期将调整，使得失业率|回到自然失业率，无论通胀如何|变化。
#
# 这些理论都为理解和分析|失业与通货膨胀的关系提供了框架|，但实际经济情况可能会因各种|因素而复杂化。||Tokens Used: 375
# 	Prompt Tokens: 18
# 	Completion Tokens: 357
# Successful Requests: 1
# Total Cost (CYN): ¥0.0075
